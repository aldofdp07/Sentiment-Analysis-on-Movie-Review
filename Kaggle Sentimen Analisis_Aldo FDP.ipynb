# %%
import csv
import pandas as pd
import random
import pickle
import numpy as np
import tensorflow as tf
import zipfile
import warnings
warnings.simplefilter("ignore")


from tensorflow.keras.models import Sequential
from keras.layers import Dense, Embedding, LSTM, SpatialDropout1D
from tensorflow.keras.utils import to_categorical 
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
EMBEDDING_DIM = 100
MAXLEN = 16
TRUNCATING = 'post'
PADDING = 'post'
OOV_TOKEN = "<OOV>"
MAX_EXAMPLES = 5000
TRAINING_SPLIT = 0.9

# %%
# !wget https://github.com/aldofdp07/Sentiment-Analysis-on-Movie-Review/blob/main/sentiment-analysis-on-movie-reviews.zip
# Out:
# --2022-11-06 11:53:14--  https://github.com/aldofdp07/Sentiment-Analysis-on-Movie-Review/blob/main/Dataset/sampleSubmission.csv
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sampleSubmission.csv’
#
# sampleSubmission.cs     [ <=>                ] 149.03K  --.-KB/s    in 0.1s
#
# 2022-11-06 11:53:15 (1.50 MB/s) - ‘sampleSubmission.csv’ saved [152602]
#
# --2022-11-06 11:53:15--  https://github.com/aldofdp07/Sentiment-Analysis-on-Movie-Review/blob/main/Dataset/test.tsv
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘test.tsv’
#
# test.tsv                [ <=>                ] 143.80K  --.-KB/s    in 0.07s
#
# 2022-11-06 11:53:15 (1.94 MB/s) - ‘test.tsv’ saved [147250]
#
# --2022-11-06 11:53:15--  https://github.com/aldofdp07/Sentiment-Analysis-on-Movie-Review/blob/main/Dataset/train.tsv
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘train.tsv’
#
# train.tsv               [ <=>                ] 143.86K  --.-KB/s    in 0.07s
#
# 2022-11-06 11:53:15 (1.92 MB/s) - ‘train.tsv’ saved [147310]

# %%
# !unzip /content/sentiment-analysis-on-movie-reviews.zip
# Out:
# Archive:  /content/sentiment-analysis-on-movie-reviews.zip
# replace sampleSubmission.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: sampleSubmission.csv
#   inflating: test.tsv.zip
#   inflating: train.tsv.zip

# %%
train = pd.read_csv('/content/train.tsv.zip',sep = '\t')
test = pd.read_csv('/content/test.tsv.zip',sep = '\t')

train.head()
# Out:
#    PhraseId  SentenceId                                             Phrase  \
# 0         1           1  A series of escapades demonstrating the adage ...
# 1         2           1  A series of escapades demonstrating the adage ...
# 2         3           1                                           A series
# 3         4           1                                                  A
# 4         5           1                                             series
#
#    Sentiment
# 0          1
# 1          2
# 2          2
# 3          2
# 4          2

# %%
def train_val_split(sentences, labels, training_split):
    
    train_data, validation_data, train_labels, validation_labels = train_test_split(sentences, labels, train_size=training_split, random_state=24)
    return train_data, validation_data, train_labels, validation_labels
    
    return train_data, validation_data, train_labels, validation_labels

# %%
# Test your function
sentences = train["Phrase"]
labels = train["Sentiment"]
train_sentences, val_sentences, train_labels, val_labels = train_val_split(sentences, labels, TRAINING_SPLIT)

print(f"There are {len(train_sentences)} sentences for training.\n")
print(f"There are {len(train_labels)} labels for training.\n")
print(f"There are {len(val_sentences)} sentences for validation.\n")
print(f"There are {len(val_labels)} labels for validation.")
# Out:
# There are 140454 sentences for training.
#
# There are 140454 labels for training.
#
# There are 15606 sentences for validation.
#
# There are 15606 labels for validation.

# %%
def fit_tokenizer(train_sentences, oov_token):
    
    ### START CODE HERE
        # Instantiate the Tokenizer class, passing in the correct values for num_words and oov_token
    tokenizer = Tokenizer(oov_token = oov_token, filters='!"#$%&()*+,-./:;<=>?@[\]^_`{|}~', lower=True)
        # Fit the tokenizer to the training sentences
    tokenizer.fit_on_texts(train_sentences)
    ### END CODE HERE  
    return tokenizer

# %%
# Test your function
tokenizer = fit_tokenizer(train_sentences, OOV_TOKEN)

word_index = tokenizer.word_index
vocab_size = len(word_index)

print(f"Vocabulary contains {vocab_size} words\n")
print("<OOV> token included in vocabulary" if "<OOV>" in word_index else "<OOV> token NOT included in vocabulary")
# Out:
# Vocabulary contains 15284 words
#
# <OOV> token included in vocabulary

# %%
print(word_index)
# Out:
# {'<OOV>': 1, 'the': 2, 'a': 3, 'of': 4, 'and': 5, 'to': 6, "'s": 7, 'in': 8, 'is': 9, 'that': 10, 'it': 11, 'as': 12, 'with': 13, 'for': 14, 'its': 15, 'film': 16, 'an': 17, 'movie': 18, 'this': 19, 'but': 20, 'be': 21, 'on': 22, 'you': 23, "n't": 24, 'by': 25, 'more': 26, 'his': 27, 'one': 28, 'about': 29, 'not': 30, 'at': 31, 'from': 32, 'or': 33, 'than': 34, 'all': 35, 'like': 36, 'have': 37, 'are': 38, 'has': 39, "'": 40, 'so': 41, 'out': 42, 'story': 43, 'rrb': 44, 'up': 45, 'who': 46, 'good': 47, 'too': 48, 'most': 49, 'into': 50, 'lrb': 51, 'if': 52, 'time': 53, 'what': 54, 'no': 55, 'their': 56, 'much': 57, 'characters': 58, "''": 59, 'comedy': 60, 'i': 61, 'your': 62, 'can': 63, 'just': 64, 'life': 65, 'does': 66, 'some': 67, 'even': 68, 'little': 69, 'funny': 70, 'will': 71, 'well': 72, 'way': 73, 'very': 74, 'been': 75, 'any': 76, 'make': 77, 'only': 78, 'he': 79, 'which': 80, 'movies': 81, 'director': 82, 'do': 83, 'love': 84, 'new': 85, 'bad': 86, 'there': 87, 'her': 88, 'enough': 89, 'work': 90, 'was': 91, 'own': 92, 'us': 93, 'they': 94, 'made': 95, 'other': 96, 'something': 97, 'old': 98, 'two': 99, 'action': 100, 'would': 101, 'never': 102, 'we': 103, 'through': 104, 'best': 105, 'many': 106, 'off': 107, 'people': 108, 'when': 109, 'self': 110, 'character': 111, 'them': 112, 'makes': 113, 'how': 114, 'world': 115, 'first': 116, 'may': 117, 'over': 118, 'plot': 119, 'could': 120, 'films': 121, 'see': 122, 'drama': 123, 'being': 124, 'better': 125, 'look': 126, 'big': 127, 'long': 128, 'audience': 129, 'those': 130, 'feel': 131, 'really': 132, 'sense': 133, 'man': 134, 'without': 135, 'great': 136, 'every': 137, 'real': 138, 'humor': 139, 'another': 140, 'screen': 141, 'ever': 142, "'re": 143, 'get': 144, 'few': 145, 'should': 146, 'hollywood': 147, 'such': 148, 'year': 149, 'minutes': 150, 'both': 151, 'still': 152, 'performances': 153, 'cast': 154, 'down': 155, 'fun': 156, 'human': 157, 'while': 158, 'family': 159, 'between': 160, 'performance': 161, 'heart': 162, 'nothing': 163, 'often': 164, 'less': 165, 'hard': 166, 'were': 167, 'american': 168, 'might': 169, 'kind': 170, 'far': 171, 'things': 172, 'had': 173, 'these': 174, 'also': 175, 'moments': 176, 'before': 177, 'script': 178, 'seen': 179, 'acting': 180, 'end': 181, 'after': 182, 'our': 183, 'original': 184, 'back': 185, 'young': 186, 'right': 187, 'rather': 188, 'watch': 189, 'full': 190, 'interesting': 191, 'entertaining': 192, 'because': 193, 'almost': 194, 'picture': 195, 'thriller': 196, 'emotional': 197, 'my': 198, 'material': 199, 'cinema': 200, 'go': 201, 'actors': 202, 'here': 203, 'tale': 204, 'music': 205, 'dialogue': 206, "'ve": 207, 'take': 208, 'war': 209, 'lot': 210, 'find': 211, 'quite': 212, 'scenes': 213, 'half': 214, 'times': 215, 'me': 216, 'come': 217, 'itself': 218, 'same': 219, 'yet': 220, 'watching': 221, 'years': 222, 'style': 223, 'romantic': 224, 'him': 225, 'star': 226, 'going': 227, 'kids': 228, 'documentary': 229, 'high': 230, 'comes': 231, 'making': 232, 'thing': 233, 'history': 234, 'give': 235, 'special': 236, 'subject': 237, 'though': 238, 'worth': 239, 'women': 240, 'seems': 241, 'dark': 242, "'ll": 243, 'point': 244, 'ca': 245, 'last': 246, 'comic': 247, 'anything': 248, 'art': 249, 'seem': 250, 'where': 251, 'keep': 252, 'hour': 253, 'feels': 254, 'show': 255, 'did': 256, 'compelling': 257, 'three': 258, 'video': 259, 'want': 260, 'works': 261, 'least': 262, 'bit': 263, 'around': 264, 'visual': 265, 'together': 266, 'ultimately': 267, 'think': 268, 'sometimes': 269, 'care': 270, 'takes': 271, 'true': 272, 'writer': 273, 'sweet': 274, 'gets': 275, 'actually': 276, 'entertainment': 277, 'looking': 278, 'say': 279, 'piece': 280, 'under': 281, 'direction': 282, 'familiar': 283, 'pretty': 284, 'fans': 285, 'again': 286, 'place': 287, 'away': 288, 'low': 289, 'day': 290, 'she': 291, 'flick': 292, 'part': 293, 'face': 294, 'why': 295, 'genre': 296, 'set': 297, 'feature': 298, 'know': 299, 'moving': 300, 'need': 301, 'cinem ...

# %%
def seq_pad_and_trunc(sentences, tokenizer, padding, truncating, maxlen):
    
    ### START CODE HERE     
    # Convert sentences to sequences
    sequences = tokenizer.texts_to_sequences(sentences)
    # Pad the sequences using the correct padding, truncating and maxlen
    pad_trunc_sequences = pad_sequences(sequences, padding=padding, truncating=truncating, maxlen=maxlen)
    ### END CODE HERE
    
    return pad_trunc_sequences

# %%
# Test your function
train_pad_trunc_seq = seq_pad_and_trunc(train_sentences, tokenizer, PADDING, TRUNCATING, MAXLEN)
val_pad_trunc_seq = seq_pad_and_trunc(val_sentences, tokenizer, PADDING, TRUNCATING, MAXLEN)

print(f"Padded and truncated training sequences have shape: {train_pad_trunc_seq.shape}\n")
print(f"Padded and truncated validation sequences have shape: {val_pad_trunc_seq.shape}")
# Out:
# Padded and truncated training sequences have shape: (140454, 16)
#
# Padded and truncated validation sequences have shape: (15606, 16)

# %%
train_labels = np.array(train_labels)
val_labels = np.array(val_labels)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
train_labels = le.fit_transform(train_labels)
val_labels = le.fit_transform(val_labels)

# %%
# GRADED FUNCTION: create_model
def create_model(vocab_size, embedding_dim, maxlen):
    
    ### START CODE HERE
    model = tf.keras.Sequential([ 
        # This is how you need to set the Embedding layer when using pre-trained embeddings
        tf.keras.layers.Embedding(vocab_size+1, embedding_dim, input_length=maxlen, trainable=True),
        tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(128)),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dense(5, activation='softmax')
    ])

   # model = Sequential()
    #model.add(Embedding(vocab_size+1, embedding_dim, input_length=maxlen, weights=[embeddings_matrix], trainable=True))
    #model.add(SpatialDropout1D(0.5))
    #model.add(LSTM(100, dropout=0.5, recurrent_dropout=0.5))
    #model.add(Dense(32, activation='relu'))
    #model.add(Dense(6, activation='softmax'))
    
    model.compile(loss="sparse_categorical_crossentropy",
                  optimizer='adam',
                  metrics=['accuracy']) 

    ### END CODE HERE
    return model

# %%
# Create your untrained model
model = create_model(vocab_size, EMBEDDING_DIM, MAXLEN)

# Train the model and save the training history
history = model.fit(train_pad_trunc_seq, train_labels, epochs=15, validation_data=(val_pad_trunc_seq, val_labels))
# Out:
# Epoch 1/15
# 4390/4390 [==============================] - 332s 75ms/step - loss: 0.9263 - accuracy: 0.6234 - val_loss: 0.8411 - val_accuracy: 0.6576
# Epoch 2/15
# 4390/4390 [==============================] - 328s 75ms/step - loss: 0.7442 - accuracy: 0.6928 - val_loss: 0.8061 - val_accuracy: 0.6686
# Epoch 3/15
# 4390/4390 [==============================] - 328s 75ms/step - loss: 0.6666 - accuracy: 0.7217 - val_loss: 0.8135 - val_accuracy: 0.6686
# Epoch 4/15
# 4390/4390 [==============================] - 327s 75ms/step - loss: 0.6039 - accuracy: 0.7467 - val_loss: 0.8581 - val_accuracy: 0.6676
# Epoch 5/15
# 4390/4390 [==============================] - 328s 75ms/step - loss: 0.5434 - accuracy: 0.7693 - val_loss: 0.9018 - val_accuracy: 0.6623
# Epoch 6/15
# 4390/4390 [==============================] - 330s 75ms/step - loss: 0.4898 - accuracy: 0.7915 - val_loss: 1.0252 - val_accuracy: 0.6619
# Epoch 7/15
# 4390/4390 [==============================] - 331s 75ms/step - loss: 0.4422 - accuracy: 0.8108 - val_loss: 1.1384 - val_accuracy: 0.6503
# Epoch 8/15
# 4390/4390 [==============================] - 332s 76ms/step - loss: 0.3970 - accuracy: 0.8278 - val_loss: 1.2555 - val_accuracy: 0.6460
# Epoch 9/15
# 4390/4390 [==============================] - 331s 75ms/step - loss: 0.3577 - accuracy: 0.8444 - val_loss: 1.3784 - val_accuracy: 0.6432
# Epoch 10/15
# 4390/4390 [==============================] - 332s 76ms/step - loss: 0.3198 - accuracy: 0.8589 - val_loss: 1.6207 - val_accuracy: 0.6305
# Epoch 11/15
# 4390/4390 [==============================] - 332s 76ms/step - loss: 0.2868 - accuracy: 0.8716 - val_loss: 1.7915 - val_accuracy: 0.6292
# Epoch 12/15
# 4390/4390 [==============================] - 333s 76ms/step - loss: 0.2587 - accuracy: 0.8822 - val_loss: 1.9734 - val_accuracy: 0.6287
# Epoch 13/15
# 4390/4390 [==============================] - 332s 76ms/step - loss: 0.2337 - accuracy: 0.8925 - val_loss: 2.2026 - val_accuracy: 0.6242
# Epoch 14/15
# 4390/4390 [==============================] - 331s 75ms/step - loss: 0.2135 - accuracy: 0.9004 - val_loss: 2.3300 - val_accuracy: 0.6234
# Epoch 15/15
# 4390/4390 [==============================] - 332s 76ms/step - loss: 0.1949 - accuracy: 0.9073 - val_loss: 2.4737 - val_accuracy: 0.6198

# %%
sent = test["Phrase"]

tokenizer = fit_tokenizer(sent, OOV_TOKEN)

test_pad_trunc_seq = seq_pad_and_trunc(sent, tokenizer, PADDING, TRUNCATING, MAXLEN)

# %%
x = np.argmax(model.predict(test_pad_trunc_seq), axis=-1)
# Out:
# 2072/2072 [==============================] - 60s 29ms/step

# %%
test['Sentiment']=x

# %%
test = test.drop(['Phrase','SentenceId'],axis = 1)

# %%
test.head()
# Out:
#    PhraseId  Sentiment
# 0    156061          2
# 1    156062          2
# 2    156063          2
# 3    156064          2
# 4    156065          2

# %%
test.to_csv('submission_Aldofdp.csv')
